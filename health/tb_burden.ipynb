# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\user\my_snippet\DataSets\TB_Burden_Country.csv")

df.head()
# Out:
#   Country or territory name ISO 2-character country/territory code  \
# 0               Afghanistan                                     AF
# 1               Afghanistan                                     AF
# 2               Afghanistan                                     AF
# 3               Afghanistan                                     AF
# 4               Afghanistan                                     AF
#
#   ISO 3-character country/territory code  ISO numeric country/territory code  \
# 0                                    AFG                                   4
# 1                                    AFG                                   4
# 2                                    AFG                                   4
# 3                                    AFG                                   4
# 4                                    AFG                                   4
#
#   Region  Year  Estimated total population number  \
# 0    EMR  1990                           11731193
# 1    EMR  1991                           12612043
# 2    EMR  1992                           13811876
# 3    EMR  1993                           15175325
# 4    EMR  1994                           16485018
#
#    Estimated prevalence of TB (all forms) per 100 000 population  \
# 0                                              306.0
# 1                                              343.0
# 2                                              371.0
# 3                                              392.0
# 4                                              410.0
#
#    Estimated prevalence of TB (all forms) per 100 000 population, low bound  \
# 0                                              156.0
# 1                                              178.0
# 2                                              189.0
# 3                                              194.0
# 4                                              198.0
#
#    Estimated prevalence of TB (all forms) per 100 000 population, high bound  \
# 0                                              506.0
# 1                                              562.0
# 2                                              614.0
# 3                                              657.0
# 4                                              697.0
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Estimated incidence of TB cases who are HIV-positive per 100 000 population  \
# 0                                               0.11
# 1                                               0.13
# 2                                               0.16
# 3                                               0.19
# 4                                               0.21
#
#    Estimated incidence of TB cases who are HIV-positive per 100 000 population, low bound  \
# 0                                               0.08
# 1                                               0.11
# 2                                               0.14
# 3                                               0.17
# 4                                               0.18
#
#    Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound  \
# 0                                               0.14
# 1                                               0.16
# 2                                               0.18
# 3                                               0.21
# 4                                               0.24
#
#   Estimated incidence of TB cases who are HIV-positive  \
# 0                                               12.0
# 1                                               17.0
# 2                                               22.0
# 3                                               28.0
# 4                                               35.0
#
#    Estimated incidence of TB cases who are HIV-positive, low bound  \
# 0                                                9.4
# 1                                               14.0
# 2                                               19.0
# 3                                               25.0
# 4                                               30.0
#
#    Estimated incidence of TB cases who are HIV-positive, high bound  \
# 0                                               16.0
# 1                                               20.0
# 2                                               24.0
# 3                                               31.0
# 4                                               39.0
#
#    Method to derive TBHIV estimates  Case detection rate (all forms), percent  \
# 0                               NaN                                      20.0
# 1                               NaN                                      96.0
# 2                               NaN                                       NaN
# 3                               NaN                                       NaN
# 4                               NaN                                       NaN
#
#    Case detection rate (all forms), percent, low bound  \
# 0                                               15.0
# 1                                               80.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Case detection rate (all forms), percent, high bound
# 0                                               24.0
# 1                                              110.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 47 columns]

# %%
# cleaning
nulls = df.isnull().sum()
df = df.dropna(subset=['Country or territory name'])
duplicates = df.duplicated().sum()#0
print(f'Null Values: {nulls[nulls>0]},\
      Duplicates: {duplicates}')
# Out:
# Null Values: ISO 2-character country/territory code                                                        24
# Estimated prevalence of TB (all forms) per 100 000 population, low bound                      20
# Estimated prevalence of TB (all forms) per 100 000 population, high bound                     20
# Estimated prevalence of TB (all forms), low bound                                             20
# Estimated prevalence of TB (all forms), high bound                                            20
# Estimated mortality of TB cases who are HIV-positive, per 100 000 population, low bound     1942
# Estimated mortality of TB cases who are HIV-positive, per 100 000 population, high bound    1942
# Estimated number of deaths from TB in people who are HIV-positive, low bound                1942
# Estimated number of deaths from TB in people who are HIV-positive, high bound               1942
# Estimated incidence (all forms) per 100 000 population, low bound                             94
# Estimated incidence (all forms) per 100 000 population, high bound                            94
# Estimated number of incident cases (all forms), low bound                                     94
# Estimated number of incident cases (all forms), high bound                                    94
# Method to derive incidence estimates                                                        2133
# Estimated HIV in incident TB (percent)                                                      1475
# Estimated HIV in incident TB (percent), low bound                                           1478
# Estimated HIV in incident TB (percent), high bound                                          1478
# Estimated incidence of TB cases who are HIV-positive per 100 000 population                 1475
# Estimated incidence of TB cases who are HIV-positive per 100 000 population, low bound      1478
# Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound     1478
# Estimated incidence of TB cases who are HIV-positive                                        1475
# Estimated incidence of TB cases who are HIV-positive, low bound                             1478
# Estimated incidence of TB cases who are HIV-positive, high bound                            1478
# Method to derive TBHIV estimates                                                            5120
# Case detection rate (all forms), percent                                                     449
# Case detection rate (all forms), percent, low bound                                          449
# Case detection rate (all forms), percent, high bound                                         449
# dtype: int64,      Duplicates: 0

# %%
df.describe()
# Out:
#        ISO numeric country/territory code         Year  \
# count                         5120.000000  5120.000000
# mean                           433.576563  2001.549023
# std                            255.116018     6.933272
# min                              4.000000  1990.000000
# 25%                            212.000000  1996.000000
# 50%                            430.000000  2002.000000
# 75%                            646.000000  2008.000000
# max                            894.000000  2013.000000
#
#        Estimated total population number  \
# count                       5.120000e+03
# mean                        2.915671e+07
# std                         1.183725e+08
# min                         1.129000e+03
# 25%                         5.601190e+05
# 50%                         5.172118e+06
# 75%                         1.752404e+07
# max                         1.385567e+09
#
#        Estimated prevalence of TB (all forms) per 100 000 population  \
# count                                        5120.000000
# mean                                          194.386100
# std                                           259.016385
# min                                             0.000000
# 25%                                            23.000000
# 50%                                            85.000000
# 75%                                           272.000000
# max                                          1762.000000
#
#        Estimated prevalence of TB (all forms) per 100 000 population, low bound  \
# count                                        5100.000000
# mean                                          101.815353
# std                                           145.259349
# min                                             0.110000
# 25%                                            10.000000
# 50%                                            40.000000
# 75%                                           139.000000
# max                                          1316.000000
#
#        Estimated prevalence of TB (all forms) per 100 000 population, high bound  \
# count                                        5100.000000
# mean                                          321.006367
# std                                           421.326139
# min                                             0.770000
# 25%                                            43.000000
# 50%                                           147.000000
# 75%                                           447.000000
# max                                          3038.000000
#
#        Estimated prevalence of TB (all forms)  \
# count                            5.120000e+03
# mean                             6.654332e+04
# std                              3.249488e+05
# min                              0.000000e+00
# 25%                              3.800000e+02
# 50%                              4.300000e+03
# 75%                              2.700000e+04
# max                              4.600000e+06
#
#        Estimated prevalence of TB (all forms), low bound  \
# count                                       5.100000e+03
# mean                                        4.615915e+04
# std                                         2.711918e+05
# min                                         2.000000e-02
# 25%                                         1.700000e+02
# 50%                                         2.100000e+03
# 75%                                         1.400000e+04
# max                                         4.000000e+06
#
#        Estimated prevalence of TB (all forms), high bound  \
# count                                       5.100000e+03
# mean                                        9.319791e+04
# std                                         3.938631e+05
# min                                         1.600000e-01
# 25%                                         7.200000e+02
# 50%                                         7.700000e+03
# 75%                                         4.500000e+04
# max                                         5.200000e+06
#
#        Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population  \
# count                                        5120.000000
# mean                                           20.174426
# std                                            32.893800
# min                                             0.000000
# 25%                                             1.300000
# 50%                                             5.400000
# 75%                                            25.000000
# max                                           278.000000
#
#        ...  \
# count  ...
# mean   ...
# std    ...
# min    ...
# 25%    ...
# 50%    ...
# 75%    ...
# max    ...
#
#        Estimated incidence of TB cases who are HIV-positive per 100 000 population  \
# count                                        3645.000000
# mean                                           40.228274
# std                                           125.175567
# min                                             0.000000
# 25%                                             0.190000
# 50%                                             2.100000
# 75%                                            14.000000
# max                                          1063.000000
#
#        Estimated incidence of TB cases who are HIV-positive per 100 000 population, low bound  \
# count                                        3642.000000
# mean                                           33.892320
# std                                           105.557348
# min                                             0.000000
# 25%                                             0.130000
# 50%                                             1.700000
# 75%                                            12.000000
# max                                           981.000000
#
#        Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound  \
# count                                        3642.000000
# mean                                           47.326378
# std                                           147.004849
# min                                             0.000000
# 25%                                             0.240000
# 50%                                             2.600000
# 75%                                            17.000000
# max                                          1438.000000
#
#        Estimated incidence of TB cases who are HIV-positive  \
# count                                        3645.000000
# mean                                         6095.426979
# std                                         22807.804792
# min                                             0.000000
# 25%                                            18.000000
# 50%                                           170.000000
# 75%                                          1700.000000
# max                                        320000.000000
#
#        Estimated incidence of TB cases who are HIV-positive, low bound  \
# count                                        3642.000000
# mean                                         5215.147573
# std                                         19993.703601
# min                                             0.000000
# 25%                                            12.000000
# 50%                                           130.000000
# 75%                                          1400.000000
# max                                        290000.000000
#
#        Estimated incidence of TB cases who are HIV-positive, high bound  \
# count                                        3642.000000
# mean                                         7363.644445
# std                                         26548.834113
# min                                             0.010000
# 25%                                            25.000000
# 50%                                           220.000000
# 75%                                          2000.000000
# max                                        350000.000000
#
#        Method to derive TBHIV estimates  \
# count                               0.0
# mean                                NaN
# std                                 NaN
# min                                 NaN
# 25%                                 NaN
# 50%                                 NaN
# 75%                                 NaN
# max                                 NaN
#
#        Case detection rate (all forms), percent  \
# count                               4671.000000
# mean                                  68.217851
# std                                   25.465391
# min                                    0.000000
# 25%                                   52.000000
# 50%                                   75.000000
# 75%                                   87.000000
# max                                  320.000000
#
#        Case detection rate (all forms), percent, low bound  \
# count                                        4671.000000
# mean                                           61.959409
# std                                            23.603155
# min                                             0.000000
# 25%                                            46.000000
# 50%                                            68.000000
# 75%                                            77.000000
# max                                           270.000000
#
#        Case detection rate (all forms), percent, high bound
# count                                        4671.000000
# mean                                           75.854492
# std                                            29.277633
# min                                             0.000000
# 25%                                            59.000000
# 50%                                            82.000000
# 75%                                            95.000000
# max                                           380.000000
#
# [8 rows x 40 columns]

# %%
df.drop(columns=['ISO 2-character country/territory code','ISO numeric country/territory code',
       'Estimated prevalence of TB (all forms) per 100 000 population, low bound',
       'Estimated prevalence of TB (all forms) per 100 000 population, high bound',
       'Estimated prevalence of TB (all forms), low bound',
       'Estimated prevalence of TB (all forms), high bound',
       'Estimated number of deaths from TB (all forms, excluding HIV), low bound',
       'Estimated number of deaths from TB (all forms, excluding HIV), high bound',
       ])
# Out:
#      Country or territory name ISO 3-character country/territory code Region  \
# 0                  Afghanistan                                    AFG    EMR
# 1                  Afghanistan                                    AFG    EMR
# 2                  Afghanistan                                    AFG    EMR
# 3                  Afghanistan                                    AFG    EMR
# 4                  Afghanistan                                    AFG    EMR
# ...                        ...                                    ...    ...
# 5115                  Zimbabwe                                    ZWE    AFR
# 5116                  Zimbabwe                                    ZWE    AFR
# 5117                  Zimbabwe                                    ZWE    AFR
# 5118                  Zimbabwe                                    ZWE    AFR
# 5119                  Zimbabwe                                    ZWE    AFR
#
#       Year  Estimated total population number  \
# 0     1990                           11731193
# 1     1991                           12612043
# 2     1992                           13811876
# 3     1993                           15175325
# 4     1994                           16485018
# ...    ...                                ...
# 5115  2009                           12888918
# 5116  2010                           13076978
# 5117  2011                           13358738
# 5118  2012                           13724317
# 5119  2013                           14149648
#
#       Estimated prevalence of TB (all forms) per 100 000 population  \
# 0                                                 306.0
# 1                                                 343.0
# 2                                                 371.0
# 3                                                 392.0
# 4                                                 410.0
# ...                                                 ...
# 5115                                              449.0
# 5116                                              415.0
# 5117                                              417.0
# 5118                                              425.0
# 5119                                              409.0
#
#       Estimated prevalence of TB (all forms)  \
# 0                                    36000.0
# 1                                    43000.0
# 2                                    51000.0
# 3                                    59000.0
# 4                                    68000.0
# ...                                      ...
# 5115                                 58000.0
# 5116                                 54000.0
# 5117                                 56000.0
# 5118                                 58000.0
# 5119                                 58000.0
#
#      Method to derive prevalence estimates  \
# 0                                predicted
# 1                                predicted
# 2                                predicted
# 3                                predicted
# 4                                predicted
# ...                                    ...
# 5115                             predicted
# 5116                             predicted
# 5117                             predicted
# 5118                             predicted
# 5119                             predicted
#
#       Estimated mortality of TB cases (all forms, excluding HIV) per 100 000 population  \
# 0                                                  37.0
# 1                                                  46.0
# 2                                                  54.0
# 3                                                  60.0
# 4                                                  65.0
# ...                                                 ...
# 5115                                               39.0
# 5116                                               36.0
# 5117                                               38.0
# 5118                                               41.0
# 5119                                               40.0
#
#       Estimated mortality of TB cases (all forms, excluding HIV), per 100 000 population, low bound  \
# 0                                                  24.0
# 1                                                  29.0
# 2                                                  34.0
# 3                                                  38.0
# 4                                                  41.0
# ...                                                 ...
# 5115                                               27.0
# 5116                                               25.0
# 5117                                               26.0
# 5118                                               27.0
# 5119                                               25.0
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 5115  ...
# 5116  ...
# 5117  ...
# 5118  ...
# 5119  ...
#
#       Estimated incidence of TB cases who are HIV-positive per 100 000 population  \
# 0                                                  0.11
# 1                                                  0.13
# 2                                                  0.16
# 3                                                  0.19
# 4                                                  0.21
# ...                                                 ...
# 5115                                             511.00
# 5116                                             487.00
# 5117                                             448.00
# 5118                                             411.00
# 5119                                             395.00
#
#       Estimated incidence of TB cases who are HIV-positive per 100 000 population, low bound  \
# 0                                                  0.08
# 1                                                  0.11
# 2                                                  0.14
# 3                                                  0.17
# 4                                                  0.18
# ...                                                 ...
# 5115                                             460.00
# 5116                                             433.00
# 5117                                             403.00
# 5118                                             362.00
# 5119                                             341.00
#
#       Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound  \
# 0                                                  0.14
# 1                                                  0.16
# 2                                                  0.18
# 3                                                  0.21
# 4                                                  0.24
# ...                                                 ...
# 5115                                             566.00
# 5116                                             545.00
# 5117                                             502.00
# 5118                                             471.00
# 5119                                             464.00
#
#       Estimated incidence of TB cases who are HIV-positive  \
# 0                                                  12.0
# 1                                                  17.0
# 2                                                  22.0
# 3                                                  28.0
# 4                                                  35.0
# ...                                                 ...
# 5115                                            66000.0
# 5116                                            64000.0
# 5117                                            60000.0
# 5118                                            56000.0
# 5119                                            56000.0
#
#       Estimated incidence of TB cases who are HIV-positive, low bound  \
# 0                                                   9.4
# 1                                                  14.0
# 2                                                  19.0
# 3                                                  25.0
# 4                                                  30.0
# ...                                                 ...
# 5115                                            59000.0
# 5116                                            57000.0
# 5117                                            54000.0
# 5118                                            50000.0
# 5119                                            48000.0
#
#       Estimated incidence of TB cases who are HIV-positive, high bound  \
# 0                                                  16.0
# 1                                                  20.0
# 2                                                  24.0
# 3                                                  31.0
# 4                                                  39.0
# ...                                                 ...
# 5115                                            73000.0
# 5116                                            71000.0
# 5117                                            67000.0
# 5118                                            65000.0
# 5119                                            66000.0
#
#       Method to derive TBHIV estimates  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 5115                               NaN
# 5116                               NaN
# 5117                               NaN
# 5118                               NaN
# 5119                               NaN
#
#       Case detection rate (all forms), percent  \
# 0                                         20.0
# 1                                         96.0
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 5115                                      50.0
# 5116                                      53.0
# 5117                                      48.0
# 5118                                      45.0
# 5119                                      42.0
#
#      Case detection rate (all forms), percent, low bound  \
# 0                                                  15.0
# 1                                                  80.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5115                                               45.0
# 5116                                               48.0
# 5117                                               43.0
# 5118                                               40.0
# 5119                                               36.0
#
#       Case detection rate (all forms), percent, high bound
# 0                                                  24.0
# 1                                                 110.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5115                                               54.0
# 5116                                               59.0
# 5117                                               53.0
# 5118                                               52.0
# 5119                                               49.0
#
# [5120 rows x 39 columns]

# %%
df = df.iloc[:,1::3]

# %%
df.shape
# Out:
# (5120, 16)
